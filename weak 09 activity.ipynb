# %% [markdown]
# 1. Explain the dataset
# 2. Check the summary statistics and discuss the max, min, avg, median,
# and percentiles.
# 3. The manager wants to find out whether the same amount was spent
# for the three advertisements (TV , Radio and Newspaper). Comment
# on your findings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the dataset into python

# %%
data=pd.read_csv(r'C:\Users\Abhilash\Downloads\Advertising.csv')

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # Explaining the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# Data having 200 rows and 5 columns and there is no null values in the dataset

# %%
data=data.drop('Unnamed: 0',axis=1)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# There is a good correlation between sales and amount spent for TV add.Sales and amount spent for newspaper add is very poorly correlated

# %%
Sales=data['Sales']
sns.distplot(Sales)
plt.show()
# Out:
# C:\Users\Abhilash\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Sales data distribution follows normal distribution with slight positive skewness

# %%
plt.figure(figsize=(10,4))
plt.plot(data['TV'],label='TV')
plt.plot(data['Radio'],label='Radio')
plt.plot(data['Newspaper'],label='Newspaper')
plt.title('Amount spent on Advertisement')
plt.legend()
plt.show()

# %% [markdown]
# From the plot its very clear that amount spent for TV add is very much higher than the amount spent with Radio and Newspaper

# %% [markdown]
# # Checking the summary statistics

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Insights:-

# %% [markdown]
# Maximum amount spent for add is for TV(296.40).second is for newspaper.The maximum amount spent for all 3 add is 27.

# %% [markdown]
# Minimum amount spent for Radio is 0.00 and next for newspaper.the least amount spent altogether is 1.60

# %% [markdown]
# Average sales amount for 3 adds is 14.02.The average is high for TV and then for newspaper

# %% [markdown]
# Median or 50% amount spent for TV-149.75,Radio-22.90,Newspaper-25.75

# %% [markdown]
# The 75% and 25% percentile for sales of 3 adds is 17.40 and10.375 respectively.And the 75% is high for TV -218.82 and low for radio-36.525.The 25% is high for Tv-74.375 and low for Radio-9.975

# %% [markdown]
# # Finding out whether the same amount was spent for the three advertisements

# %% [markdown]
# ### H0=mean amount spent for all the 3 adds are equal

# %% [markdown]
# ### H1=mean amount spent for the 3 adds differs

# %%
from scipy.stats import f_oneway
f_oneway(data['TV'],data['Radio'],data['Newspaper'])
# Out:
# F_onewayResult(statistic=358.8514595342597, pvalue=4.552931539744962e-103)

# %% [markdown]
# Here p value almost equal to zero and less than 0.5.So that we can reject the null hypothesis.From this testing we can conclude that amount spent for 3 adds are different.

# %% [markdown]
# ### Submitted by group 2 - Jibin K Joy,Abdul Vahid K,Nimisha A,Chandni N P,Aparna E K
